# %% [markdown]
# # A1: About Me, Data Interests, and Skills Self-Check
#
# **DSA 405 · Week 1**
#
# | | |
# |---|---|
# | **Assigned** | Friday, Aug 21 |
# | **A1 due** | Thursday, Aug 27, 11:59 PM |
# | **Also due Thu Aug 27** | **P0** Workspace (separate handout) |
# | **Time** | ~30–40 min |

# %% [markdown]
# ---
# ## Task 1: About you
#
# Answer in this cell, two or three sentences
# 1. DHIKSHITHA, 200622069, and ENGINEERING MANAGEMENT**
# 2. **Programming.** R, PYTHON , SQL, MS ACCESS, HTML,CSS- OVER 3 YEARS OF EXPERIANCE AND INTERMIDIATE EXPERIANCE
#
# 3. **A dataset of personal interest.** I AM INTERESTED IN HEALTHCARE ANALYTICS AND MARKETING ANALYTICS DATASET
#    .
# 4. **One thing to be able to do by Week 14** TO BE PROFICIENT WITH TOOLS AND TECHNIQUES AND BE COMFORTABLE IN DATA CLEANING.
#
# *Answers here.*

# %% [markdown]
# ## Task 2: Skills Self-Check result
#
# Run `DSA405_SkillsSelfCheck_FA26.ipynb` (posted with the Week 0 material, ~20 minutes),
# then report the result below. The number is not graded; a 3/13 and a 13/13 earn identical
# credit here. The counts are used to set the pace of Week 2.
#
# If the notebook recommended the Bridge, state whether you plan to complete it before Week 2.

# %%
self_check_score = ...        # your count out of 13
group = "..."                 # the group the notebook printed (1, 2, or 3)

print(f"self-check: {self_check_score}/13, group {group}")

# %% [markdown]
# ## Task 3: Three project sparks
#
# The project (55% of the course grade; see the specification and tier descriptions posted
# this week) starts from a question about data of your choosing. Nothing is committed until
# P1 (due Thu Sep 3). List three **candidate directions**, one line each:
#
# > the question + where the data might come from
#
# Example: *"Have Wake County restaurant scores drifted over five years? County open-data
# portal."* Rough candidates are acceptable; most will be discarded before P1. Post all
# three to the **Moodle Forum** before class on Aug 28.
#
# *Three directions, one line each.*

# %% [markdown]
# ## Task 4: The AI ground rules, in your own words
#
# Read the **"AI Use Policy"** in the course supplemental information. Then answer, one or two sentences each:
#
# 1. What are the three things the policy asks of you?
# 2. At a Bench Check, what must you be able to do with code you submitted?
# 3. What AI tools (if any) do you currently use most often?
#
# *Answers here.*

# %% [markdown]
# ---
# ## AI use note
#
# List the tools used on A1 and what each was used for. If none, write "none." One or two
# sentences. (Task 4 covers why this note appears on every assignment.)
#
# *Answer here.*

# %% [markdown]
# ---
# ## Submitting
#
# 1. **Runtime > Restart runtime**, then **Run all**. The code cell should print the
#    self-check line without errors.
# 2. `File > Download > Download .ipynb`
# 3. Rename to `DSA405_002_FA26_A1_[yourUnityID].ipynb`
# 4. Upload to the **A1** space on Moodle by **Thursday, Aug 27, 11:59 PM**.
#
# **P0** (workspace setup) is due the same night as a separate submission. Its handout is
# `DSA405_P0_Workspace_FA26.md`.
