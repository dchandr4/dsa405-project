# %% [markdown]
# <a href="https://colab.research.google.com/github/dchandr4/dsa405-project/blob/main/DSA405_002_FA26_P1_%5B200622069%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1. The Question
Do hybrid vehicles achieve better fuel economy than comparable gasoline vehicles.

Helps consumers deciding between hybrid and gasoline vehicles because better fuel economy can reduce fuel costs and environmental impact.

2. Sources & Access Evidence

Source 1: EPA Automotive Trends Data
Publisher: U.S. Environmental Protection Agency (EPA)
URL: EPA Automotive Trends Data
Coverage: Model years 1975–2025;
Approximate size: The 2024 Fuel Economy and Technology CSV is 443 KB.
Access: download CSV.


url = "https://www.epa.gov/automotive-trends/explore-automotive-trends-data"


Source 2: NHTSA vPIC API
Publisher: National Highway Traffic Safety Administration (NHTSA)
URL: NHTSA vPIC API
Coverage: U.S. vehicle information  for model years 1981 onward.
Approximate size: 25+ API endpoints
Access: API.
url = "https://vpic.nhtsa.dot.gov/api/vehicles/GetModelsForMakeYear/make/Toyota/modelyear/2024?format=json"


Possible failure point: The NHTSA API is the least trusted source because it has automated traffic rate controls and if access fails, I will use the EPA data for variables available

3. Constraints & Guardrails

EPA: The EPA data are public government data, Trends data .

NHTSA- explicitly provides APIs for developers and researchers,

4. This project fits Tier 1 because it uses two public government sources.

AI Use Note

I used ChatGPT to help identify appropriate public automobile data sources
